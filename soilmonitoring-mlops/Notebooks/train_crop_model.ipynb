# %%
# Cell 1: Install and import libraries
import pandas as pd
import numpy as np
import boto3
import sagemaker
from sagemaker import get_execution_role
from sagemaker.inputs import TrainingInput
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import io
import json

print("✅ Libraries imported")
print(f"SageMaker version: {sagemaker.__version__}")

# Get SageMaker session and role
sagemaker_session = sagemaker.Session()
role = get_execution_role()
bucket = 'soilmonitoring-models'
prefix = 'xgboost-crop'

print(f"SageMaker role: {role}")
print(f"S3 bucket: {bucket}")
print(f"S3 prefix: {prefix}")
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# ✅ Libraries imported
# SageMaker version: 2.254.1
# SageMaker role: arn:aws:iam::065126182608:role/LabRole
# S3 bucket: soilmonitoring-models
# S3 prefix: xgboost-crop

# %%
# Cell 2: Load and prepare data for XGBoost
print("📂 Loading dataset...")

# Load CSV
df = pd.read_csv('Crop_recommendation.csv')

# Remove unnamed index if exists
if 'Unnamed: 0' in df.columns:
    df = df.drop('Unnamed: 0', axis=1)

print(f"Dataset shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")
print(f"\nFirst 5 rows:")
display(df.head())

# Features and target
feature_columns = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']
target_column = 'label'

X = df[feature_columns]
y = df[target_column]

print(f"\n✅ Features: {feature_columns}")
print(f"✅ Target: {target_column}")
print(f"✅ Number of crops: {y.nunique()}")
print(f"\n🌾 Crops: {sorted(y.unique())}")
# Out:
# 📂 Loading dataset...
# Dataset shape: (2200, 8)
# Columns: ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label']
#
# First 5 rows:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# ✅ Features: ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']
# ✅ Target: label
# ✅ Number of crops: 22
#
# 🌾 Crops: ['apple', 'banana', 'blackgram', 'chickpea', 'coconut', 'coffee', 'cotton', 'grapes', 'jute', 'kidneybeans', 'lentil', 'maize', 'mango', 'mothbeans', 'mungbean', 'muskmelon', 'orange', 'papaya', 'pigeonpeas', 'pomegranate', 'rice', 'watermelon']

# %%
# Cell 3: Encode labels and split data
print("🔧 Encoding labels...")

# Encode crop names to numbers (XGBoost needs numeric labels)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

print(f"Label mapping:")
for i, crop in enumerate(label_encoder.classes_):
    print(f"  {crop}: {i}")

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, 
    test_size=0.2, 
    random_state=42,
    stratify=y_encoded
)

print(f"\n📊 Data split:")
print(f"  Training: {len(X_train)} samples")
print(f"  Testing: {len(X_test)} samples")

# Save label encoder for later
import joblib
joblib.dump(label_encoder, 'crop_label_encoder_xgboost.pkl')
print(f"\n✅ Label encoder saved")
# Out:
# 🔧 Encoding labels...
# Label mapping:
#   apple: 0
#   banana: 1
#   blackgram: 2
#   chickpea: 3
#   coconut: 4
#   coffee: 5
#   cotton: 6
#   grapes: 7
#   jute: 8
#   kidneybeans: 9
#   lentil: 10
#   maize: 11
#   mango: 12
#   mothbeans: 13
#   mungbean: 14
#   muskmelon: 15
#   orange: 16
#   papaya: 17
#   pigeonpeas: 18
#   pomegranate: 19
#   rice: 20
#   watermelon: 21
#
# 📊 Data split:
#   Training: 1760 samples
#   Testing: 440 samples
#
# ✅ Label encoder saved

# %%
# Cell 4: Create training data in XGBoost format
print("📝 Preparing data for SageMaker XGBoost...")

# XGBoost expects: label, feature1, feature2, ...
# No header, label first

# Training data
train_data = pd.concat([
    pd.Series(y_train, name='label'),
    X_train.reset_index(drop=True)
], axis=1)

# Test data
test_data = pd.concat([
    pd.Series(y_test, name='label'),
    X_test.reset_index(drop=True)
], axis=1)

print(f"Training data shape: {train_data.shape}")
print(f"Test data shape: {test_data.shape}")
print(f"\nFirst 3 rows of training data:")
display(train_data.head(3))

# Save to CSV (no header, no index)
train_file = 'train.csv'
test_file = 'test.csv'

train_data.to_csv(train_file, header=False, index=False)
test_data.to_csv(test_file, header=False, index=False)

print(f"\n✅ Saved: {train_file}")
print(f"✅ Saved: {test_file}")
# Out:
# 📝 Preparing data for SageMaker XGBoost...
# Training data shape: (1760, 8)
# Test data shape: (440, 8)
#
# First 3 rows of training data:
#    label   N    P    K  temperature   humidity        ph    rainfall
# 0     16   0   18   14    29.771494  92.007200  7.207991  114.416179
# 1      7   9  122  201    29.587484  80.919344  5.570291   68.064173
# 2      9  11   71   24    21.140114  22.718235  5.606620  141.605672
# ✅ Saved: train.csv
# ✅ Saved: test.csv

# %%
# Cell 5: Upload training data to S3
print("📤 Uploading data to S3...")

s3_client = boto3.client('s3')

# Upload training data
train_s3_path = f'{prefix}/train/train.csv'
test_s3_path = f'{prefix}/test/test.csv'

s3_client.upload_file('train.csv', bucket, train_s3_path)
s3_client.upload_file('test.csv', bucket, test_s3_path)

train_input = f's3://{bucket}/{train_s3_path}'
test_input = f's3://{bucket}/{test_s3_path}'

print(f"✅ Training data: {train_input}")
print(f"✅ Test data: {test_input}")

# Also upload label encoder
encoder_s3_path = f'{prefix}/artifacts/crop_label_encoder_xgboost.pkl'
s3_client.upload_file('crop_label_encoder_xgboost.pkl', bucket, encoder_s3_path)
print(f"✅ Label encoder: s3://{bucket}/{encoder_s3_path}")
# Out:
# 📤 Uploading data to S3...
# ✅ Training data: s3://soilmonitoring-models/xgboost-crop/train/train.csv
# ✅ Test data: s3://soilmonitoring-models/xgboost-crop/test/test.csv
# ✅ Label encoder: s3://soilmonitoring-models/xgboost-crop/artifacts/crop_label_encoder_xgboost.pkl

# %%
# Cell 6: Get XGBoost container image
from sagemaker.image_uris import retrieve

print("🐳 Getting XGBoost container image...")

# Get XGBoost container for your region
region = boto3.Session().region_name
container = retrieve('xgboost', region, version='1.5-1')

print(f"Region: {region}")
print(f"XGBoost container: {container}")
# Out:
# 🐳 Getting XGBoost container image...
# Region: us-east-1
# XGBoost container: 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.5-1

# %%
# Cell 7: Train XGBoost model with SageMaker
print("🤖 Configuring XGBoost training job...")

from sagemaker.estimator import Estimator

# Define output path
output_path = f's3://{bucket}/{prefix}/output'

# Create XGBoost estimator
xgboost_estimator = Estimator(
    image_uri=container,
    role=role,
    instance_count=1,
    instance_type='ml.m5.large',  # Training instance
    output_path=output_path,
    sagemaker_session=sagemaker_session,
    base_job_name='xgboost-crop-recommendation'
)

# Set hyperparameters
xgboost_estimator.set_hyperparameters(
    objective='multi:softmax',  # Multi-class classification
    num_class=len(label_encoder.classes_),  # Number of crop types
    num_round=100,  # Number of boosting rounds
    max_depth=6,
    eta=0.3,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric='merror'  # Multi-class error
)

print("✅ XGBoost estimator configured")
print(f"Number of classes: {len(label_encoder.classes_)}")
print(f"Output path: {output_path}")

# Prepare data channels
train_channel = TrainingInput(train_input, content_type='text/csv')
test_channel = TrainingInput(test_input, content_type='text/csv')

print("\n🚀 Starting training job...")
print("⏰ This will take 5-10 minutes...")

# Start training
xgboost_estimator.fit({
    'train': train_channel,
    'validation': test_channel
})

print("\n✅ Training complete!")
# Out:
# INFO:sagemaker:Creating training-job with name: xgboost-crop-recommendation-2025-11-22-21-09-08-426
# 🤖 Configuring XGBoost training job...
# ✅ XGBoost estimator configured
# Number of classes: 22
# Output path: s3://soilmonitoring-models/xgboost-crop/output
#
# 🚀 Starting training job...
# ⏰ This will take 5-10 minutes...
# 2025-11-22 21:09:09 Starting - Starting the training job...
# 2025-11-22 21:09:25 Starting - Preparing the instances for training...
# 2025-11-22 21:09:47 Downloading - Downloading input data...
# 2025-11-22 21:10:30 Downloading - Downloading the training image......
# 2025-11-22 21:11:41 Training - Training image download completed. Training in progress.
# 2025-11-22 21:11:41 Uploading - Uploading generated training model/miniconda3/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [2025-11-22 21:11:32.733 ip-10-0-226-198.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2025-11-22 21:11:32.759 ip-10-0-226-198.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2025-11-22:21:11:33:INFO] Imported framework sagemaker_xgboost_container.training
# [2025-11-22:21:11:33:INFO] Failed to parse hyperparameter eval_metric value merror to Json.
# Returning the value itself
# [2025-11-22:21:11:33:INFO] Failed to parse hyperparameter objective value multi:softmax to Json.
# Returning the value itself
# [2025-11-22:21:11:33:INFO] No GPUs detected (normal if no gpus installed)
# [2025-11-22:21:11:33:INFO] Running XGBoost Sagemaker in algorithm mode
# [2025-11-22:21:11:33:INFO] Determined 0 GPU(s) available on the instance.
# [2025-11-22:21:11:33:INFO] Determined delimiter of CSV input is ','
# [2025-11-22:21:11:33:INFO] Determined delimiter of CSV input is ','
# [2025-11-22:21:11:33:INFO] files path: /opt/ml/input/data/train
# [2025-11-22:21:11:33:INFO] Determined delimiter of CSV input is ','
# [2025-11-22:21:11:33:INFO] files path: /opt/ml/input/data/validation
# [2025-11-22:21:11:33:INFO] Determined delimiter of CSV input is ','
# [2025-11-22:21:11:33:INFO] Single node training.
# [2025-11-22:21:11:33:INFO] Train matrix has 1760 rows and 7 columns
# [2025-11-22:21:11:33:INFO] Validation matrix has 440 rows
# [2025-11-22 21:11:33.198 ip-10-0-226-198.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2025-11-22 21:11:33.199 ip-10-0-226-198.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2025-11-22 21:11:33.200 ip-10-0-226-198.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2025-11-22 21:11:33.200 ip-10-0-226-198.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2025-11-22:21:11:33:INFO] Debug hook created from config
# [2025-11-22 21:11:33.235 ip-10-0-226-198.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2025-11-22 21:11:33.239 ip-10-0-226-198.ec2.internal:7 INFO hook.py:491] Hook is writing from the hook with pid: 7
# [0]#011train-merror:0.03807#011validation-merror:0.07955
# [1]#011train-merror:0.02216#011validation-merror:0.02500
# [2]#011train-merror:0.01648#011validation-merror:0.02500
# [3]#011train-merror:0.01080#011validation-merror:0.01591
# [4]#011train-merror:0.00625#011validation-merror:0.01364
# [5]#011train-merror:0.00511#011validation-merror:0.01364
# [6]#011train-merror:0.00341#011validation-merror:0.00909
# [7]#011train-merror:0.00057#011validation-merror:0.00909
# [8]#011train-merror:0.00114#011validation-merror:0.00909
# [9]#011train-merror:0.00114#011validation-merror:0.00909
# [10]#011train-merror:0.00057#011validation-merror:0.00909
# [11]#011train-merror:0.00057#011validation-merror:0.00682
# [12]#011train-merror:0.00000#011validation-merror:0.00682
# [13]#011train-merror:0.00000#011validation-merror:0.00682
# [68]#011train-merror:0.00000#011validation-merror:0.00455
# [69]#011train-merror:0.00000#011validation-merror:0.00455
# [70]#011train-merror:0.00000#011validation-merror:0.00455
# [71]#011train-merror:0.00000#011validation-merror:0.00455
# [72]#011train-merror:0.00000#011validation-merror:0.00455
# [73]#011train-merror:0.00000#011validation-merror:0.00455
# [74]#011train-merror:0.00000#011validation-merror:0.00455
# [75]#011train-merror:0.00000#011validation-merror:0.00455
# [76]#011train-merror:0.00000#011validation-merror:0.00455
# [77]#011train-merror:0.00000#011validation-merror:0.00455
# [78]#011train-merror:0.00000#011validation-merror:0.00455
# [79]#011train-merror:0.00000#011validation-merror:0.00455
# [80]#011train-merror:0.00000#011validation-merror:0.00455
# [81]#011train-merror:0.00000#011validation-merror:0.00455
# [82]#011train-merror:0.00000#011validation-merror:0.00455
# [83]#011train-merror:0.00000#011validation-merror:0.00455
# [84]#011train-merror:0.00000#011validation-merror:0.00455
# [85]#011train-merror:0.00000#011validation-merror:0.00455
# [86]#011train-merror:0.00000#011validation-merror:0.00455
# [87]#011train-merror:0.00000#011validation-merror:0.00455
# [88]#011train-merror:0.00000#011validation-merror:0.00455
# [89]#011train-merror:0.00000#011validation-merror:0.00455
# [90]#011train-merror:0.00000#011validation-merror:0.00455
# [91]#011train-merror:0.00000#011validation-merror:0.00455
# [92]#011train-merror:0.00000#011validation-merror:0.00455
# [93]#011train-merror:0.00000#011validation-merror:0.00455
# [94]#011train-merror:0.00000#011validation-merror:0.00455
# [95]#011train-merror:0.00000#011validation-merror:0.00455
# [96]#011train-merror:0.00000#011validation-merror:0.00455
# [97]#011train-merror:0.00000#011validation-merror:0.00455
# [98]#011train-merror:0.00000#011validation-merror:0.00455
# [99]#011train-merror:0.00000#011validation-merror:0.00455
#
# 2025-11-22 21:11:54 Completed - Training job completed
# Training seconds: 127
# Billable seconds: 127
#
# ✅ Training complete!

# %%
import boto3
import pandas as pd

runtime = boto3.client("sagemaker-runtime")
endpoint_name = "xgboost-crop-endpoint"

# Example row
df = pd.DataFrame({
    "N": [0],
    "P": [18],
    "K": [14],
    "temperature": [29.771494],
    "humidity": [92.007200],
    "ph": [7.207991],
    "rainfall": [114.416179],
})

payload = df.to_csv(index=False, header=False).strip()

response = runtime.invoke_endpoint(
    EndpointName=endpoint_name,
    ContentType="text/csv",
    Body=payload
)

raw_pred = response["Body"].read().decode("utf-8").strip()
pred_class = int(float(raw_pred))

label_map = {
    0: "apple",
    1: "banana",
    2: "blackgram",
    3: "chickpea",
    4: "coconut",
    5: "coffee",
    6: "cotton",
    7: "grapes",
    8: "jute",
    9: "kidneybeans",
    10: "lentil",
    11: "maize",
    12: "mango",
    13: "mothbeans",
    14: "mungbean",
    15: "muskmelon",
    16: "orange",
    17: "papaya",
    18: "pigeonpeas",
    19: "pomegranate",
    20: "rice",
    21: "watermelon",
}  # insert mapping above

print("Predicted class:", pred_class)
print("Predicted crop:", label_map[pred_class])
# Out:
# Predicted class: 16
# Predicted crop: orange
